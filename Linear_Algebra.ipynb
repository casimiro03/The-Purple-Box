# %%
import numpy as np
import matplot.pyplot as plt

# Vector operations examples based on khan academy
v = np.array([2, -1, 3])
w = np.array([0, 5, -2])
c = 4
print("c*v =", c*v)   # [ 8 -4 12] Scalar multiplication
print("v+w =", v+w)   # [2 4 1] vectoer addition
print("v-w =", v-w)   # [ 2 -6  5] vector subtraction
